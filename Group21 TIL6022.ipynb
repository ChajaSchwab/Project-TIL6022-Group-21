# %% [markdown]
# # Project Group -
#
# Members:
#
# Student numbers:

# %% [markdown]
# # Research Objective
#
# *Requires data modeling and quantitative research in Transport, Infrastructure & Logistics*

# %% [markdown]
# # Contribution Statement
#
# *Be specific. Some of the tasks can be coding (expect everyone to do this), background research, conceptualisation, visualisation, data analysis, data modelling*

# %% [markdown]
# **Author 1**:
#
# **Author 2**:
#
# **Author 3**:

# %% [markdown]
# # Data Used

# %% [markdown]
# # Data Pipeline

# %%
import pandas as pd

filepath = r'C:\Users\zijlm\Downloads\ttr00012 (1).tsv.gz'

airtraffic_df = pd.read_csv(filepath, sep='\t')

airtraffic_df
# Out:
#    unit,tra_meas,tra_cov,schedule,geo\time       2010        2011   \
# 0                 PAS,PAS_CRD,TOTAL,TOT,AT   23532455    25137612
# 1                 PAS,PAS_CRD,TOTAL,TOT,BE   22697764    25102695
# 2                 PAS,PAS_CRD,TOTAL,TOT,BG    6169323     6652007
# 3                 PAS,PAS_CRD,TOTAL,TOT,CH   37615959    41439848
# 4                 PAS,PAS_CRD,TOTAL,TOT,CY    6948288     7190387
# 5                 PAS,PAS_CRD,TOTAL,TOT,CZ   12242386    12650532
# 6                 PAS,PAS_CRD,TOTAL,TOT,DE  166130833   175316076
# 7                 PAS,PAS_CRD,TOTAL,TOT,DK   24334687    25808321
# 8                 PAS,PAS_CRD,TOTAL,TOT,EE    1381062     1907569
# 9                 PAS,PAS_CRD,TOTAL,TOT,EL   32588072    33770739
# 10                PAS,PAS_CRD,TOTAL,TOT,ES  153387014   165153230
# 11         PAS,PAS_CRD,TOTAL,TOT,EU27_2007  774555432   818145231
# 12         PAS,PAS_CRD,TOTAL,TOT,EU27_2020  687720194   730656231
# 13              PAS,PAS_CRD,TOTAL,TOT,EU28  776047580   819727379
# 14                PAS,PAS_CRD,TOTAL,TOT,FI   14220636    16374398
# 15                PAS,PAS_CRD,TOTAL,TOT,FR  118697207   126013257
# 16                PAS,PAS_CRD,TOTAL,TOT,HR    4677414     4989236
# 17                PAS,PAS_CRD,TOTAL,TOT,HU    8174510     8884837
# 18                PAS,PAS_CRD,TOTAL,TOT,IE   23094210    23362889
# 19                PAS,PAS_CRD,TOTAL,TOT,IS    2036356     2462894
# 20                PAS,PAS_CRD,TOTAL,TOT,IT  109064953   116226667
# 21                PAS,PAS_CRD,TOTAL,TOT,LT    2282834     2691991
# 22                PAS,PAS_CRD,TOTAL,TOT,LU    1613696     1836780
# 23                PAS,PAS_CRD,TOTAL,TOT,LV    4655898     5098360
# 24                PAS,PAS_CRD,TOTAL,TOT,ME          :           :
# 25                PAS,PAS_CRD,TOTAL,TOT,MK          :           :
# 26                PAS,PAS_CRD,TOTAL,TOT,MT    3293548     3506814
# 27                PAS,PAS_CRD,TOTAL,TOT,NL   48618879    53895292
# 28                PAS,PAS_CRD,TOTAL,TOT,NO   29518449    32403522
# 29                PAS,PAS_CRD,TOTAL,TOT,PL   18383115    20635672
# 30                PAS,PAS_CRD,TOTAL,TOT,PT   25735500    27579707
# 31                PAS,PAS_CRD,TOTAL,TOT,RO    8848949     9687456
# 32                PAS,PAS_CRD,TOTAL,TOT,RS          :           :
# 33                PAS,PAS_CRD,TOTAL,TOT,SE   26646764    29732247
# 34                PAS,PAS_CRD,TOTAL,TOT,SI    1382341     1358792
# 35                PAS,PAS_CRD,TOTAL,TOT,SK    1881844     1808187
# 36                PAS,PAS_CRD,TOTAL,TOT,UK  192887734   201536753
#
#          2012        2013        2014        2015       2016        2017   \
